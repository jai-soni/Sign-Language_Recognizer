# %%
# !git clone https://github.com/ardamavi/Sign-Language-Digits-Dataset.git
# Out:
# Cloning into 'Sign-Language-Digits-Dataset'...
# remote: Enumerating objects: 2089, done.
# remote: Total 2089 (delta 0), reused 0 (delta 0), pack-reused 2089
# Receiving objects: 100% (2089/2089), 15.07 MiB | 27.16 MiB/s, done.
# Resolving deltas: 100% (658/658), done.

# %%
# !pip install tqdm
# Out:
# Requirement already satisfied: tqdm in /usr/local/lib/python3.6/dist-packages (4.28.1)

# %%
import os, cv2, math
from keras.models import Sequential
from keras.layers import Conv2D
from keras.layers import MaxPooling2D
from keras.layers import Flatten
from keras.layers import Dense
from keras.layers import Dropout
from keras.preprocessing.image import ImageDataGenerator
from keras.utils import plot_model
import numpy as np
from keras.preprocessing import image
from sklearn.model_selection import train_test_split
from shutil import copyfile
from tqdm import tqdm
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %% [markdown]
# This project is run using google collab GPU.

# %%
nrow, ncol = 7, 4
plt.rcParams['figure.figsize'] = (ncol*3, nrow*3)
for row in range(nrow):
    for col in range(ncol):
        img_index = row*ncol+col
        # load image
        img = image.load_img('Sign-Language-Digits-Dataset/Examples/example_' + str(img_index) + '.JPG', target_size = (64, 64))
        plt.subplot(nrow, ncol, img_index + 1)
        plt.imshow(img)
        plt.title(img_index)
        plt.axis('off')

# %% [markdown]
# This project aims to create a classifier that can intepret sign language for number 0 to 9. The image of the sign language for respective number is shown above.
#
# Inside 'Sign-Language-Digits-Dataset/Dataset/', the images of different sign language are organised according to their labels(i.e. 0 to 9). The dataset will first be divided into 3 sets : training_set, validation_set, and test_set. The size of training set, validation set, and test set are 70%, 15% and 15% of the whole dataset respectively.
#
# To accomodate for the requirement for flow_from_directory method from keras, I will reorganise the images in the following structure :
#
# * Training set : 'Sign-Language-Digits-Dataset/Dataset/training_set/class_00/image_file'
# * Validation set : 'Sign-Language-Digits-Dataset/Dataset/validation_set/class_00/image_file'
# * Test set : 'Sign-Language-Digits-Dataset/Dataset/test_set/class_00/image_file'

# %%
DATASET_PATH = 'Sign-Language-Digits-Dataset/Dataset/'

# %%
# Creating a list of filename for training set, validation set, and test set
train_set = {}
validation_set = {}
test_set = {}
for cat in os.listdir(DATASET_PATH):
  cat_dir = os.path.join(DATASET_PATH, cat) # e.g. DATASET_PATH/'0'
  cat_files = os.listdir(cat_dir)
  # Training set's size is 70% of the data
  train_list , test_list = train_test_split(cat_files, test_size = 0.3)
  # Validation set's and Test set's size are both 15% of the data
  validation_list, test_list = train_test_split(test_list, test_size = 0.5)
  train_set[cat] = train_list
  validation_set[cat] = validation_list
  test_set[cat] = test_list

# %%
for cat in tqdm(train_set.keys()):
  cat_dir = os.path.join(DATASET_PATH, 'training_set', 'class_0' + str(cat))
  os.makedirs(cat_dir)
  for file in train_set[cat]:
    # src path is DATASET_PATH/'0'/file
    src = os.path.join(DATASET_PATH, cat, file)
    # dest path is DATASET_PATH/'training_set'/'class_00'
    # to accomodate for the directory format required by flow_from_directory method in keras
    dest = os.path.join(cat_dir, file)
    copyfile(src, dest)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 57.21it/s]

# %%
for cat in tqdm(validation_set.keys()):
  cat_dir = os.path.join(DATASET_PATH, 'validation_set', 'class_0' + str(cat))
  os.makedirs(cat_dir)
  for file in validation_set[cat]:
    # src path is DATASET_PATH/'0'/file
    src = os.path.join(DATASET_PATH, cat, file)
    # dest path is DATASET_PATH/'validation_set'/'class_00'
    # to accomodate for the directory format required by flow_from_directory method in keras
    dest = os.path.join(cat_dir, file)
    copyfile(src, dest)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 225.16it/s]

# %%
for cat in tqdm(test_set.keys()):
  cat_dir = os.path.join(DATASET_PATH, 'test_set', 'class_0' + str(cat))
  os.makedirs(cat_dir)
  for file in test_set[cat]:
    # src path is DATASET_PATH/'0'/file
    src = os.path.join(DATASET_PATH, cat, file)
    # dest path is DATASET_PATH/'test_set'/'class_00'
    # to accomodate for the directory format required by flow_from_directory method in keras
    dest = os.path.join(cat_dir, file)
    copyfile(src, dest)
# Out:
# 100%|██████████| 10/10 [00:00<00:00, 229.22it/s]

# %%
for i in range(10):
  train_size = len(train_set[str(i)])
  validation_size = len(validation_set[str(i)])
  test_size = len(test_set[str(i)])
  print("0{} : Training size({}) Validation size({}) Test size({})".format(i, train_size, validation_size, test_size))
# Out:
# 00 : Training size(143) Validation size(31) Test size(31)
# 01 : Training size(144) Validation size(31) Test size(31)
# 02 : Training size(144) Validation size(31) Test size(31)
# 03 : Training size(144) Validation size(31) Test size(31)
# 04 : Training size(144) Validation size(31) Test size(32)
# 05 : Training size(144) Validation size(31) Test size(32)
# 06 : Training size(144) Validation size(31) Test size(32)
# 07 : Training size(144) Validation size(31) Test size(31)
# 08 : Training size(145) Validation size(31) Test size(32)
# 09 : Training size(142) Validation size(31) Test size(31)

# %% [markdown]
# Data augmentation is performed on the training set images so that the classifier can learn any changes with respect to scaling, horizontal_flip, or others.

# %%
# Performing data augmentation on training dataset
train_datagen = ImageDataGenerator(rescale = 1./255,
                                   shear_range = 0.2,
                                   zoom_range = 0.2,
                                   horizontal_flip = True)

# For validation dataset, only rescale the pictures
validation_datagen = ImageDataGenerator(rescale = 1./255)

# For test dataset, only rescale the pictures
test_datagen = ImageDataGenerator(rescale = 1./255)

training_data = train_datagen.flow_from_directory(os.path.join(DATASET_PATH, 'training_set'),
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

validation_data = validation_datagen.flow_from_directory(os.path.join(DATASET_PATH, 'validation_set'),
                                                 target_size = (64, 64),
                                                 batch_size = 32,
                                                 class_mode = 'categorical')

test_data = test_datagen.flow_from_directory(os.path.join(DATASET_PATH, 'test_set'),
                                            target_size = (64, 64),
                                            batch_size = 32,
                                            class_mode = 'categorical')
# Out:
# Found 1438 images belonging to 10 classes.
# Found 310 images belonging to 10 classes.
# Found 314 images belonging to 10 classes.

# %% [markdown]
# For this dataset, I will be using the following infrastructure.

# %%
# Initialising the CNN
classifier = Sequential()

# Adding first convolutional layer, followed by pooling, and dropout
classifier.add(Conv2D(32, (3, 3), input_shape = (64, 64, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Dropout(0.25))

# Adding second convolutional layer, followed by pooling, and dropout
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Dropout(0.25))

# Adding third convolutional layer, followed by pooling, and dropout
classifier.add(Conv2D(32, (3, 3), activation = 'relu'))
classifier.add(MaxPooling2D(pool_size = (2, 2)))
classifier.add(Dropout(0.25))

# Flattening
classifier.add(Flatten())

# Full connection
classifier.add(Dense(units = 128, activation = 'relu'))
classifier.add(Dense(units = 10, activation = 'softmax'))

# Compiling the CNN
classifier.compile(optimizer = 'adam', loss = 'categorical_crossentropy', metrics = ['accuracy'])
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/keras/backend/tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.

# %%
# Train the data with training set, and check the result with validation accuracy
history = classifier.fit_generator(training_data,
                         steps_per_epoch = math.ceil(training_data.n / training_data.batch_size),
                         epochs = 100,
                         validation_data = validation_data,
                         validation_steps = math.ceil(validation_data.n / validation_data.batch_size))
# Out:
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/100
# 45/45 [==============================] - 10s 218ms/step - loss: 2.3118 - acc: 0.1007 - val_loss: 2.2987 - val_acc: 0.1032
# Epoch 2/100
# 45/45 [==============================] - 6s 138ms/step - loss: 2.2819 - acc: 0.1447 - val_loss: 2.1742 - val_acc: 0.2903
# Epoch 3/100
# 45/45 [==============================] - 6s 140ms/step - loss: 2.0176 - acc: 0.3019 - val_loss: 1.4956 - val_acc: 0.4968
# Epoch 4/100
# 45/45 [==============================] - 6s 138ms/step - loss: 1.4587 - acc: 0.5008 - val_loss: 1.0866 - val_acc: 0.6613
# Epoch 5/100
# 45/45 [==============================] - 6s 137ms/step - loss: 1.1884 - acc: 0.5918 - val_loss: 0.8320 - val_acc: 0.7613
# Epoch 6/100
# 45/45 [==============================] - 6s 138ms/step - loss: 1.0461 - acc: 0.6619 - val_loss: 0.7126 - val_acc: 0.7677
# Epoch 7/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.9430 - acc: 0.6892 - val_loss: 0.5983 - val_acc: 0.8323
# Epoch 8/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.8289 - acc: 0.7373 - val_loss: 0.5127 - val_acc: 0.8516
# Epoch 9/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.7177 - acc: 0.7505 - val_loss: 0.4949 - val_acc: 0.8484
# Epoch 10/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.6615 - acc: 0.7802 - val_loss: 0.4466 - val_acc: 0.8613
# Epoch 11/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.6073 - acc: 0.8075 - val_loss: 0.4011 - val_acc: 0.8871
# Epoch 12/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.5094 - acc: 0.8345 - val_loss: 0.3742 - val_acc: 0.8774
# Epoch 13/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.4687 - acc: 0.8546 - val_loss: 0.3803 - val_acc: 0.8903
# Epoch 14/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.4898 - acc: 0.8332 - val_loss: 0.2872 - val_acc: 0.9000
# Epoch 15/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.4565 - acc: 0.8491 - val_loss: 0.2618 - val_acc: 0.9161
# Epoch 16/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.4386 - acc: 0.8443 - val_loss: 0.2588 - val_acc: 0.9194
# Epoch 17/100
# 45/45 [==============================] - 6s 137ms/step - loss: 0.3856 - acc: 0.8692 - val_loss: 0.2480 - val_acc: 0.9226
# Epoch 18/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.3684 - acc: 0.8783 - val_loss: 0.2488 - val_acc: 0.9226
# Epoch 19/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.3298 - acc: 0.8866 - val_loss: 0.2133 - val_acc: 0.9290
# Epoch 20/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.3109 - acc: 0.8979 - val_loss: 0.2338 - val_acc: 0.9161
# Epoch 21/100
# 45/45 [==============================] - 6s 141ms/step - loss: 0.2846 - acc: 0.9053 - val_loss: 0.2026 - val_acc: 0.9323
# Epoch 22/100
# 45/45 [==============================] - 6s 136ms/step - loss: 0.2783 - acc: 0.9096 - val_loss: 0.2128 - val_acc: 0.9194
# Epoch 23/100
# 45/45 [==============================] - 6s 137ms/step - loss: 0.2626 - acc: 0.9285 - val_loss: 0.1939 - val_acc: 0.9452
# Epoch 24/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.2820 - acc: 0.9186 - val_loss: 0.2070 - val_acc: 0.9258
# Epoch 25/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.2450 - acc: 0.9152 - val_loss: 0.1627 - val_acc: 0.9516
# Epoch 26/100
# 45/45 [==============================] - 6s 137ms/step - loss: 0.2606 - acc: 0.9152 - val_loss: 0.1489 - val_acc: 0.9484
# Epoch 27/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.2315 - acc: 0.9263 - val_loss: 0.1465 - val_acc: 0.9452
# Epoch 28/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.2140 - acc: 0.9303 - val_loss: 0.1534 - val_acc: 0.9484
# Epoch 29/100
# 45/45 [==============================] - 6s 137ms/step - loss: 0.2026 - acc: 0.9332 - val_loss: 0.1441 - val_acc: 0.9452
# Epoch 30/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1937 - acc: 0.9354 - val_loss: 0.1434 - val_acc: 0.9387
# Epoch 31/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.1834 - acc: 0.9354 - val_loss: 0.1246 - val_acc: 0.9516
# Epoch 32/100
# 45/45 [==============================] - 6s 137ms/step - loss: 0.1953 - acc: 0.9353 - val_loss: 0.1437 - val_acc: 0.9516
# Epoch 33/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1855 - acc: 0.9464 - val_loss: 0.1361 - val_acc: 0.9548
# Epoch 34/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1660 - acc: 0.9471 - val_loss: 0.1302 - val_acc: 0.9516
# Epoch 35/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1713 - acc: 0.9388 - val_loss: 0.1010 - val_acc: 0.9581
# Epoch 36/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.1653 - acc: 0.9424 - val_loss: 0.1322 - val_acc: 0.9516
# Epoch 37/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.1608 - acc: 0.9458 - val_loss: 0.1123 - val_acc: 0.9548
# Epoch 38/100
# 45/45 [==============================] - 6s 137ms/step - loss: 0.1380 - acc: 0.9520 - val_loss: 0.1041 - val_acc: 0.9613
# Epoch 39/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1264 - acc: 0.9624 - val_loss: 0.0948 - val_acc: 0.9613
# Epoch 40/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1359 - acc: 0.9485 - val_loss: 0.1026 - val_acc: 0.9677
# Epoch 41/100
# 45/45 [==============================] - 6s 136ms/step - loss: 0.1270 - acc: 0.9569 - val_loss: 0.0974 - val_acc: 0.9613
# Epoch 42/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.1448 - acc: 0.9493 - val_loss: 0.0863 - val_acc: 0.9710
# Epoch 43/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.1426 - acc: 0.9506 - val_loss: 0.0963 - val_acc: 0.9548
# Epoch 44/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.1298 - acc: 0.9597 - val_loss: 0.1047 - val_acc: 0.9645
# Epoch 45/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.1119 - acc: 0.9603 - val_loss: 0.0882 - val_acc: 0.9677
# Epoch 46/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.1117 - acc: 0.9575 - val_loss: 0.0953 - val_acc: 0.9613
# Epoch 47/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.1334 - acc: 0.9576 - val_loss: 0.1107 - val_acc: 0.9548
# Epoch 48/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1049 - acc: 0.9674 - val_loss: 0.1387 - val_acc: 0.9516
# Epoch 49/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1160 - acc: 0.9603 - val_loss: 0.1525 - val_acc: 0.9645
# Epoch 50/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.1253 - acc: 0.9603 - val_loss: 0.1036 - val_acc: 0.9613
# Epoch 51/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1206 - acc: 0.9561 - val_loss: 0.1087 - val_acc: 0.9677
# Epoch 52/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1020 - acc: 0.9660 - val_loss: 0.1347 - val_acc: 0.9613
# Epoch 53/100
# 45/45 [==============================] - 6s 137ms/step - loss: 0.1114 - acc: 0.9652 - val_loss: 0.1257 - val_acc: 0.9548
# Epoch 54/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.1046 - acc: 0.9660 - val_loss: 0.1495 - val_acc: 0.9581
# Epoch 55/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.1143 - acc: 0.9680 - val_loss: 0.1326 - val_acc: 0.9452
# Epoch 56/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.1222 - acc: 0.9624 - val_loss: 0.1281 - val_acc: 0.9581
# Epoch 57/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0778 - acc: 0.9729 - val_loss: 0.0905 - val_acc: 0.9774
# Epoch 58/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0885 - acc: 0.9708 - val_loss: 0.1133 - val_acc: 0.9613
# Epoch 59/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0748 - acc: 0.9736 - val_loss: 0.1241 - val_acc: 0.9710
# Epoch 60/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0929 - acc: 0.9707 - val_loss: 0.1192 - val_acc: 0.9645
# Epoch 61/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0837 - acc: 0.9694 - val_loss: 0.1087 - val_acc: 0.9581
# Epoch 62/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.1178 - acc: 0.9611 - val_loss: 0.0879 - val_acc: 0.9710
# Epoch 63/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0890 - acc: 0.9674 - val_loss: 0.0887 - val_acc: 0.9645
# Epoch 64/100
# 45/45 [==============================] - 6s 137ms/step - loss: 0.0762 - acc: 0.9750 - val_loss: 0.0803 - val_acc: 0.9613
# Epoch 65/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0679 - acc: 0.9756 - val_loss: 0.0963 - val_acc: 0.9710
# Epoch 66/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0907 - acc: 0.9673 - val_loss: 0.0696 - val_acc: 0.9645
# Epoch 67/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0820 - acc: 0.9764 - val_loss: 0.1079 - val_acc: 0.9645
# Epoch 68/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0631 - acc: 0.9770 - val_loss: 0.0850 - val_acc: 0.9774
# Epoch 69/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0661 - acc: 0.9812 - val_loss: 0.0732 - val_acc: 0.9774
# Epoch 70/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0567 - acc: 0.9840 - val_loss: 0.0711 - val_acc: 0.9742
# Epoch 71/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0834 - acc: 0.9741 - val_loss: 0.0803 - val_acc: 0.9774
# Epoch 72/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0905 - acc: 0.9687 - val_loss: 0.1282 - val_acc: 0.9548
# Epoch 73/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0634 - acc: 0.9819 - val_loss: 0.0867 - val_acc: 0.9645
# Epoch 74/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0481 - acc: 0.9833 - val_loss: 0.0714 - val_acc: 0.9742
# Epoch 75/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0563 - acc: 0.9812 - val_loss: 0.0745 - val_acc: 0.9677
# Epoch 76/100
# 45/45 [==============================] - 6s 141ms/step - loss: 0.0580 - acc: 0.9826 - val_loss: 0.0666 - val_acc: 0.9774
# Epoch 77/100
# 45/45 [==============================] - 6s 136ms/step - loss: 0.0838 - acc: 0.9694 - val_loss: 0.0754 - val_acc: 0.9742
# Epoch 78/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0649 - acc: 0.9784 - val_loss: 0.0953 - val_acc: 0.9710
# Epoch 79/100
# 45/45 [==============================] - 6s 142ms/step - loss: 0.0659 - acc: 0.9805 - val_loss: 0.0831 - val_acc: 0.9645
# Epoch 80/100
# 45/45 [==============================] - 6s 136ms/step - loss: 0.0569 - acc: 0.9806 - val_loss: 0.0577 - val_acc: 0.9806
# Epoch 81/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0562 - acc: 0.9799 - val_loss: 0.1053 - val_acc: 0.9613
# Epoch 82/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0737 - acc: 0.9763 - val_loss: 0.0764 - val_acc: 0.9774
# Epoch 83/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0595 - acc: 0.9799 - val_loss: 0.0542 - val_acc: 0.9806
# Epoch 84/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0717 - acc: 0.9784 - val_loss: 0.1073 - val_acc: 0.9677
# Epoch 85/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0653 - acc: 0.9792 - val_loss: 0.0768 - val_acc: 0.9774
# Epoch 86/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0636 - acc: 0.9798 - val_loss: 0.0562 - val_acc: 0.9839
# Epoch 87/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0757 - acc: 0.9791 - val_loss: 0.0597 - val_acc: 0.9742
# Epoch 88/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0469 - acc: 0.9840 - val_loss: 0.0418 - val_acc: 0.9903
# Epoch 89/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0721 - acc: 0.9736 - val_loss: 0.0501 - val_acc: 0.9774
# Epoch 90/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0371 - acc: 0.9889 - val_loss: 0.0420 - val_acc: 0.9806
# Epoch 91/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0651 - acc: 0.9776 - val_loss: 0.0697 - val_acc: 0.9742
# Epoch 92/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0525 - acc: 0.9832 - val_loss: 0.0696 - val_acc: 0.9677
# Epoch 93/100
# 45/45 [==============================] - 6s 137ms/step - loss: 0.0542 - acc: 0.9819 - val_loss: 0.0560 - val_acc: 0.9806
# Epoch 94/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0632 - acc: 0.9784 - val_loss: 0.0575 - val_acc: 0.9774
# Epoch 95/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0573 - acc: 0.9812 - val_loss: 0.0449 - val_acc: 0.9839
# Epoch 96/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0512 - acc: 0.9819 - val_loss: 0.0457 - val_acc: 0.9839
# Epoch 97/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0579 - acc: 0.9812 - val_loss: 0.0375 - val_acc: 0.9871
# Epoch 98/100
# 45/45 [==============================] - 6s 140ms/step - loss: 0.0543 - acc: 0.9839 - val_loss: 0.0622 - val_acc: 0.9742
# Epoch 99/100
# 45/45 [==============================] - 6s 139ms/step - loss: 0.0434 - acc: 0.9861 - val_loss: 0.0420 - val_acc: 0.9806
# Epoch 100/100
# 45/45 [==============================] - 6s 138ms/step - loss: 0.0640 - acc: 0.9833 - val_loss: 0.0553 - val_acc: 0.9806

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('Model Accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['Training', 'Validation'])

# %% [markdown]
# From the accuracy plot, the validation accuracy differs from the training accuracy by a small extent indicating absence of overfitting. When the classifier is evaluated on the test set, it obtains a relatively high accuracy.

# %%
# Accuracy of the classifier when evaluated based on the test_set
test_loss, test_accuracy = classifier.evaluate_generator(test_data, math.ceil(test_data.n / test_data.batch_size))
print("Accuracy on test set : {}".format(test_accuracy))
# Out:
# Accuracy on test set : 0.974522293373278

# %% [markdown]
# To visualise the performance of the classifier, the classifier will be used to predict all the example images for 0 to 9.

# %%
nrow, ncol = 2, 5
plt.rcParams['figure.figsize'] = (ncol*3, nrow*3)
for row in range(nrow):
    for col in range(ncol):
        img_index = row*ncol+col
        # load image
        img = image.load_img('Sign-Language-Digits-Dataset/Examples/example_' + str(img_index) + '.JPG', target_size = (64, 64))
        # convert image into array for prediction
        test_image = image.img_to_array(img)
        test_image = np.expand_dims(test_image, axis = 0)
        # predict image using classifier
        result = classifier.predict(test_image).argmax()
        plt.subplot(nrow, ncol, img_index + 1)
        plt.imshow(img)
        plt.title("Actual({}) Predicted({})".format(img_index, result))
        plt.axis('off')

# %% [markdown]
# It can be seen from above output that the classifier is able to classify all the images correctly. To save the model for future use, simply run the code below.

# %%
# save the models and weight for future purposes
# serialize model to JSON
model_json = classifier.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)
# serialize weights to HDF5
classifier.save_weights("model.h5")
print("Saved model to disk")
# Out:
# Saved model to disk

# %% [markdown]
# # Reference
#
# * https://github.com/ardamavi/Sign-Language-Digits-Dataset
# * https://www.superdatascience.com/deep-learning/
